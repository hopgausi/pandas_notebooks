# %%
from matplotlib import pyplot as plt
#print(plt.style.available)
#plt.style.use('seaborn-poster')
plt.xkcd()

# %%
data_x = [20,22,24,26,28,30,32,34,36]
data_y = [20000,23000,25000,28000,34000,40000,48000,55000, 60000]
plt.plot(data_x, data_y, color='k', linestyle='--', label='All devs')
plt.title('Medium salary(USD) based on age')
plt.xlabel('Ages')
plt.ylabel('Medium salary(USD)')
plt.grid()
plt.legend()
